# %%
import pandas as pd
import altair as alt
from outbreak_data import outbreak_data
from outbreak_tools import outbreak_tools
import requests

# %%
state_list = ['USA_US-WA', 'USA_US-CA', 'USA_US-NY', 'USA_US-LA']
states = '(' + " OR ".join(state_list) + ')'

# %%
nopage = 'fetch_all=true&page=0'
covid19_endpoint = 'covid19/query'

# %%
args_all = f'q=location_id:{states}&sort=date&fields=date,confirmed_numIncrease,admin1&{nopage}'
data_all = outbreak_data.get_outbreak_data(covid19_endpoint, args_all, collect_all=True)
# Out:
# https://api.outbreak.info/covid19/query?q=location_id:(USA_US-WA OR USA_US-CA OR USA_US-NY OR USA_US-LA)&sort=date&fields=date,confirmed_numIncrease,admin1&fetch_all=true&page=0
# 200
# https://api.outbreak.info/covid19/query?scroll_id=&fetch_all=True&page=0
# 200
# https://api.outbreak.info/covid19/query?scroll_id=&fetch_all=True&page=1
# 200
# ...

# %%
states_df = pd.DataFrame(data_all['hits'])

# %%
states_df['date'] = states_df['date'].apply(lambda x: pd.to_datetime(x))
states_df = states_df.sort_values('date')
states_df.reset_index(inplace=True, drop=True)

# %%
states_df
# Out:
#                                 _id    _score      admin1  \
# 0        USA_NewYork_None2020-02-12  8.395272    New York
# 1     USA_California_None2020-02-12  8.398540  California
# 2     USA_Washington_None2020-02-12  8.418376  Washington
# 3      USA_Louisiana_None2020-02-12  8.415042   Louisiana
# 4     USA_Washington_None2020-02-13  8.389997  Washington
# ...                             ...       ...         ...
# 3591  USA_Washington_None2022-07-28  8.442107  Washington
# 3592  USA_California_None2022-07-29  8.398540  California
# 3593  USA_Washington_None2022-07-29  8.389997  Washington
# 3594   USA_Louisiana_None2022-07-29  8.476894   Louisiana
# 3595     USA_NewYork_None2022-07-29  8.377114    New York
#
#       confirmed_numIncrease       date
# 0                         0 2020-02-12
# 1                         0 2020-02-12
# 2                         0 2020-02-12
# 3                         0 2020-02-12
# 4                         0 2020-02-13
# ...

# %% [markdown]
# ### Below is the distribution of "Confirmed # Increase" over time for California, Louisiana, New York, and Washington

# %%
outbreak_tools.plot_increase(state_list)
# Out:
# https://api.outbreak.info/covid19/query?q=location_id:(USA_US-WA OR USA_US-CA OR USA_US-NY OR USA_US-LA)&sort=date&fields=date,confirmed_rolling,admin1&fetch_all=true&page=0
# 200
# https://api.outbreak.info/covid19/query?scroll_id=FGluY2x1ZGVfY29udGV4dF91dWlkDnF1ZXJ5VGhlbkZldGNoAxZBa3JlSUZsRlJBaUR2YnYtek85T0xRAAAAAAFAq-cWMGFpWWh2OVRUUnlXZVlHZjRoVkRhZxY1TzkxQmVDQ1RURzVzSS1jM2ViR1VRAAAAAAFBrQ0WLTQ2VXcxZXZTaGlDMjg4VjVYQUtmdxY1TzkxQmVDQ1RURzVzSS1jM2ViR1VRAAAAAAFBrQ4WLTQ2VXcxZXZTaGlDMjg4VjVYQUtmdw==&fetch_all=True&page=0
# 200
# https://api.outbreak.info/covid19/query?scroll_id=FGluY2x1ZGVfY29udGV4dF91dWlkDnF1ZXJ5VGhlbkZldGNoAxZBa3JlSUZsRlJBaUR2YnYtek85T0xRAAAAAAFAq-cWMGFpWWh2OVRUUnlXZVlHZjRoVkRhZxY1TzkxQmVDQ1RURzVzSS1jM2ViR1VRAAAAAAFBrQ0WLTQ2VXcxZXZTaGlDMjg4VjVYQUtmdxY1TzkxQmVDQ1RURzVzSS1jM2ViR1VRAAAAAAFBrQ4WLTQ2VXcxZXZTaGlDMjg4VjVYQUtmdw==&fetch_all=True&page=1
# 200
# ...

# %% [markdown]
# ### Query Example

# %%
ex = outbreak_data.prevalence_by_location('USA_US-CA')
ex
# Out:
# https://api.outbreak.info/genomics/prevalence-by-location-all-lineages?location_id=USA_US-CA&sort=date&ndays=2048&nday_threshold=0&other_threshold=0
# 200
#               date  total_count  lineage_count lineage  prevalence  \
# 0       2020-02-06            1              1       a    1.000000
# 1       2020-02-07            0              0       a    0.000000
# 2       2020-02-08            0              0       a    0.000000
# 3       2020-02-09            0              0       a    0.000000
# 4       2020-02-10            0              0       a    0.000000
# ...            ...          ...            ...     ...         ...
# 112553  2022-07-04            0              0      xe    0.000000
# 112554  2022-07-05         1689              1      xe    0.000592
# 112555  2022-07-06            0              0      xe    0.000000
# 112556  2022-07-07            0              0      xe    0.000000
# 112557  2022-07-08          485              1      xe    0.002062
#
# ...

# %%
locations = ['USA_US-CA', 'California', 'awrdad']

# %%
locId_url = "https://api.outbreak.info/genomics/location?"
locIds_of_interest=[]
locIds_not_found=[]
for i in locations:
    print('Input: ', i)
    locId_arg = "name=" + i
    result = outbreak_data.get_outbreak_data('genomics/location', locId_arg)
    hits = None
    if(len(result) >= 1):
        hits = result['results']
        print(hits)
    if(len(hits) == 0):
        print('Not Found:', i)
        locIds_not_found.extend([i])
    else:
        df = pd.DataFrame(hits)
        if (df.shape[0]==1):
            print('Found Id:', df.id.unique()[0])
            locIds_of_interest.extend([df.id.unique()[0]])
        else:
            locIds_not_found.extend([i])
    print('\n')
# Out:
# Input:  USA_US-CA
# https://api.outbreak.info/genomics/location?name=USA_US-CA
# 200
# []
# Not Found: USA_US-CA
#
#
# Input:  California
# /Users/mocha/Python-outbreak-info/outbreak_data/outbreak_data.py:47: UserWarning: Warning!: Data has "results" but length of data is 0
#   warnings.warn('Warning!: Data has "results" but length of data is 0')
# https://api.outbreak.info/genomics/location?name=California
# 200
# [{'country': 'United States', 'country_id': 'USA', 'division': 'California', 'division_id': 'CA', 'id': 'USA_US-CA', 'label': 'California, United States', 'admin_level': 1, 'total_count': 661874}]
# Found Id: USA_US-CA
#
#
# Input:  awrdad
# https://api.outbreak.info/genomics/location?name=awrdad
# 200
# []
# Not Found: awrdad

# %%
locIds_of_interest
# Out:
# ['USA_US-CA']

# %%
locIds_not_found
# Out:
# ['USA_US-CA', 'awrdad']

# %%
def location_lookup(locations)
    locId_url = "https://api.outbreak.info/genomics/location?"
    locIds_of_interest=[]
    locIds_not_found=[]
    for (i in locations):
        locId_arg = "name=" + i
        results = outbreak_data.get_outbreak_data('genomics/location', locId_arg)
        hits = None
        if(length(results) >= 1):
            hits = results['results']
        if(len(hits) == 0):
            locIds_not_found = locIds_not_found.extend([i])
        else:
            df = pd.DataFrame(hits)
            if (df.shape[0]==1):
                locIds_of_interest= locIds_of_interest.extend([df.id.unique()[0]])
            else:
                locIds_not_found=locIds_not_found.extend([i])
            
        
    
    if (length(locIds_of_interest)==length(locations)):
        return(locIds_of_interest)
    if (length(locIds_of_interest)!=length(locations)):
        locations_not_found=c()
        for (i in locIds_not_found):
            if (grepl(" ", i, fixed=TRUE)==T):
                locs=paste0("*",i,"*")
            else:
                locs=paste0("*",i,"*")
            locations_not_found=c(locations_not_found, locs)

        for (i in 1:length(locations_not_found)):
            locId = paste0("name=", paste(locations_not_found[i]))
            dataurl = paste0(locId_url, locId)
            results = getGenomicsResponse(dataurl, F, logWarning = F, logError = T)
            hits = data.frame()
            if(length(results) >= 1):
                hits = rbind_pages(results)
            if(nrow(hits) == 0):
                next
            else:
                df=(hits)
                df$admin_level[df$admin_level == "-1"] = "World Bank Region"
                df$admin_level[df$admin_level == "0"] = "country"
                df$admin_level[df$admin_level == "1"] = "state/province"
                df$admin_level[df$admin_level == "1.5"] = "metropolitan area"
                df$admin_level[df$admin_level == "2"] = "county"
                df$full = paste0(df$label, " (", df$admin_level, ")")
                for (i in df$full):
                    cat(paste0(i, "\n"))
                    loc_sel = readline("Is this a location of interest? (Y/N): ")
                    if ((loc_sel == "Y")|(loc_sel == "y")):
                        locIds_of_interest = c(locIds_of_interest, df$id[df$full==i])
                        break
                    if ((loc_sel != "Y")&(loc_sel != "y")&(loc_sel != "N")&(loc_sel != "n")):
                        cat("Expected input is Y or N\n\n")
                        cat(i)
                        loc_sel = readline("Is this a location of interest? (Y/N): ")
                        if ((loc_sel == "Y")|(loc_sel == "y")):
                            locIds_of_interest = c(locIds_of_interest, df$id[df$full==i])
                            break
    return(locIds_of_interest)
# Out:
#   File "<ipython-input-14-32ba565fa58a>", line 1
#     def location_lookup(locations)
#                                   ^
# SyntaxError: invalid syntax
